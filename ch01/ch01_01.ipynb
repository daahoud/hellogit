# %% [markdown]
# # 01-01 Pythonという異世界

# %% [markdown]
# ## 読むことからはじめよう

# %%
# 1・1・1
apple = 1 # リンゴを1つ出現させる
apple = apple + 1 # リンゴを1つ増やす
print(apple) # リンゴの状態を表示する
# Out:
# 2

# %% [markdown]
# ## 道具を動かしながら前に進もう

# %%
# 最初にこのプログラムを実行してください
tokyo_avg_temp = [5.2, 6.1, 9.4, 14.7, 19.3, 22.5,
26.4, 27.7, 24.1, 18.3, 13.0, 8.4]
sapporo_avg_temp = [-3.6, -2.6, 1.2, 7.9, 13.2, 17.0,
21.3, 22.9, 18.1, 11.4, 4.5, -1.4]

# %%
# 1・1・2
import matplotlib.pyplot as plt
months = list(range(1, 13))
plt.plot(months, tokyo_avg_temp, label="Tokyo", linestyle = "dashed")
plt.plot(months, sapporo_avg_temp, label="Sapporo", linestyle = "dotted")
plt.legend()
# 注:紙面の都合上，書籍に掲載してあるプログラムに「linestyle = "dashed"」が追加してあります

# %% [markdown]
# ## 魔法を書こう(レベル2)

# %%
# このプログラムを実行してください
okinawa_avg_temp = [17.0, 17.2, 18.9, 21.6, 24.6, 27.4,
28.9, 28.7, 27.5, 25.0, 22.1, 18.7]

# %%
# 1・1・3
import matplotlib.pyplot as plt
months = list(range(1, 13))
plt.plot(months, tokyo_avg_temp, label="Tokyo", linestyle = "dashed")
plt.plot(months, sapporo_avg_temp, label="Sapporo", linestyle = "dotted")
plt.plot(months, okinawa_avg_temp, label="Okinawa", linestyle = "dashdot")
plt.legend()
# 注:紙面の都合上，書籍に掲載してあるプログラムに「linestyle = "dashed"」が追加してあります

# %% [markdown]
# 順番は前後して恐縮ですが，以下は本書に掲載した残りのプログラムになります。

# %% [markdown]
# ## 魔法の世界を広げよう

# %%
name = "ももたろう"
companions = ["イヌ", "サル"]
dumpling = 10

# %%
dumpling = dumpling - 1 # きびだんごを1個減らす

# %%
companions = companions + ["キジ"] # キジがお供に加わる

# %% [markdown]
# ## 魔法を書こう(レベル1)

# %%
dumpling = dumpling - 1

# %%
companions = companions + ["ゴリラ"]

# %% [markdown]
# ## 抽象的な世界に立ち向かおう

# %%
import numpy as np
l_mino = np.array([
[0, 1, 0],
[0, 1, 0],
[0, 1, 1]
])

# %%
transposed = l_mino.T # 転置
rotated_90 = transposed[::-1] # 行を反転

# %%
print(rotated_90)
