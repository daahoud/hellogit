# %% [markdown]
# # 02-02 数値と計算

# %% [markdown]
# ## 数値を使ってみよう

# %%
36

# %%
# 2・2・2 意味のある数値(月数)
36

# %% [markdown]
# ## 計算と算術演算子

# %%
# 2・2・3 月数×家賃(万円)
36 * 14.5
# Out:
# 522.0

# %%
# 2・2・4 522万円を年利5%で3年運用
522.0 * 1.05 ** 3
# Out:
# 604.28025

# %% [markdown]
# ## 計算の優先順位

# %%
# 2・2・5 くだものの個数(1)
3 + 5 * 4
# Out:
# 23

# %%
# 2・2・6 くだものの個数(2)
(3 + 5) * 4
# Out:
# 32
